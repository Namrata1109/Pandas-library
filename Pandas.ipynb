# %% [markdown]
# # pandas

# %% [markdown]
# pandas is a library for data manipulation

# %% [raw]
# 1. series ---->  display index (you can assign a index)
#
# 2. dataframe ----> nothing but a series of series (multiple series)

# %%
import pandas as pd
import numpy as np

# %%
lt=[{'a':10,'b':20},{'a':5,'b':10,'c':20}]

# %%
lt
# Out:
# [{'a': 10, 'b': 20}, {'a': 5, 'b': 10, 'c': 20}]

# %%
data=pd.DataFrame(lt)

# %%
data.shape
# Out:
# (2, 3)

# %%
data.size
# Out:
# 6

# %%
b=[7,8,9]

# %%
bb=pd.Series(b)

# %%
bb
# Out:
# 0    7
# 1    8
# 2    9
# dtype: int64

# %%
bb=pd.Series(b,index=['a','b','c'])

# %%
bb
# Out:
# a    7
# b    8
# c    9
# dtype: int64

# %%
a=[4,5,6]

# %%
ab=pd.Series(a)

# %%
ab
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64

# %%
ab=pd.Series(a,index=['a','b','c'])

# %%
ab
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
x=[1,2,3]

# %%
x_series=pd.Series(x)

# %%
x_series
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
l=[1,4,8]

# %%
l
# Out:
# [1, 4, 8]

# %%
l_series=pd.Series(data=l)    #S should be capital

# %%
l_series
# Out:
# 0    1
# 1    4
# 2    8
# dtype: int64

# %%
alpha_series=pd.Series(data=l,index=['a','b','c'])
alpha_series
# Out:
# a    1
# b    4
# c    8
# dtype: int64

# %%
Index = ["1st","2nd","3rd"]

# %%
alpha_series=pd.Series(data=l,index=Index)
alpha_series
# Out:
# 1st    1
# 2nd    4
# 3rd    8
# dtype: int64

# %%
duplicate = pd.Series(data=l,index=['a','a','b'])
duplicate
# Out:
# a    1
# a    4
# b    8
# dtype: int64

# %%
duplicate['a']
# Out:
# a    1
# a    4
# dtype: int64

# %%
alpha_series["3rd"]
# Out:
# 8

# %%
s=[1,3,5,7]

# %%
s_series=pd.Series(data=s)

# %%
s_series
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
duplicate=pd.Series(data=s,index=['a','b','c','c'])
duplicate
# Out:
# a    1
# b    3
# c    5
# c    7
# dtype: int64

# %%
duplicate['c']
# Out:
# c    5
# c    7
# dtype: int64

# %%
data1={'a':1,'b':4,'c':6}   # key is the index 
data1
# Out:
# {'a': 1, 'b': 4, 'c': 6}

# %%
dict_data=pd.Series(data=data1)

# %%
dict_data
# Out:
# a    1
# b    4
# c    6
# dtype: int64

# %% [markdown]
# # list using pd with dataframe.

# %%
import pandas as pd
import numpy as np

# %%
game=pd.DataFrame({'name of the game':["cricket",'hokey','hututu','badmintan'],'players':[40,30,41,35],'score':[9,7,4,8]})

# %%
game
# Out:
#   name of the game  players  score
# 0          cricket       40      9
# 1            hokey       30      7
# 2           hututu       41      4
# 3        badmintan       35      8

# %%
game['score']
# Out:
# 0    9
# 1    7
# 2    4
# 3    8
# Name: score, dtype: int64

# %%
game['players'][2]
# Out:
# 41

# %%
game['score']>20
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: score, dtype: bool

# %%
game[game['score']>20]
# Out:
# Empty DataFrame
# Columns: [name of the game, players, score]
# Index: []

# %%
game[game['score']<30]
# Out:
#   name of the game  players  score
# 0          cricket       40      9
# 1            hokey       30      7
# 2           hututu       41      4
# 3        badmintan       35      8

# %%
stud_info=pd.DataFrame({'Name of Student':['Ram','Sita','Neha','Rohit'],'Age':[23,19,18,25],'Final Marks':[90,70,60,95]})

# %%
stud_info
# Out:
#   Name of Student  Age  Final Marks
# 0             Ram   23           90
# 1            Sita   19           70
# 2            Neha   18           60
# 3           Rohit   25           95

# %%
index=[1,2,3,4]

# %%
stud_info=pd.DataFrame({'Name of Student':['Ram','Sita','Neha','Rohit'],'Age':[23,19,18,25],'Final Marks':[90,70,60,95]},index=index)

# %%
stud_info
# Out:
#   Name of Student  Age  Final Marks
# 1             Ram   23           90
# 2            Sita   19           70
# 3            Neha   18           60
# 4           Rohit   25           95

# %%
stud_info['Final Marks']
# Out:
# 1    90
# 2    70
# 3    60
# 4    95
# Name: Final Marks, dtype: int64

# %%
stud_info['Age'][4]
# Out:
# 25

# %%
stud_info['Final Marks'][1]
# Out:
# 90

# %%
stud_info['Final Marks']>70
# Out:
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Final Marks, dtype: bool

# %%
stud_info[stud_info['Final Marks']>70]
# Out:
#   Name of Student  Age  Final Marks
# 1             Ram   23           90
# 4           Rohit   25           95

# %%
stud_info[['Age','Final Marks']]
# Out:
#    Age  Final Marks
# 1   23           90
# 2   19           70
# 3   18           60
# 4   25           95

# %% [markdown]
# # practice class

# %%
import pandas as pd
import numpy as np

# %%
index=['a','b','c']

# %%
df=pd.DataFrame({'name':['sham','geeta','sudhir'],'Age':[23,67,34],'Subject1_marks':[34,78,90],'Subject2_marks':[56,78,90]},index=index)

# %%
df
# Out:
#      name  Age  Subject1_marks  Subject2_marks
# a    sham   23              34              56
# b   geeta   67              78              78
# c  sudhir   34              90              90

# %%
df['name']
# Out:
# a      sham
# b     geeta
# c    sudhir
# Name: name, dtype: object

# %%
df['Age']
# Out:
# a    23
# b    67
# c    34
# Name: Age, dtype: int64

# %%
df['Subject1_marks'],df['Subject2_marks']  #extra trick
# Out:
# (a    34
#  b    78
#  c    90
#  Name: Subject1_marks, dtype: int64,
#  a    56
#  b    78
#  c    90
#  Name: Subject2_marks, dtype: int64)

# %%
df[['Subject1_marks','Subject2_marks']]
# Out:
#    Subject1_marks  Subject2_marks
# a              34              56
# b              78              78
# c              90              90

# %%
df['Total']=df['Subject1_marks']+df['Subject2_marks']

# %%
df
# Out:
#      name  Age  Subject1_marks  Subject2_marks  Total
# a    sham   23              34              56     90
# b   geeta   67              78              78    156
# c  sudhir   34              90              90    180

# %%
df["Total"]>150 #checking the condition
# Out:
# a    False
# b     True
# c     True
# Name: Total, dtype: bool

# %%
df[df["Total"]>150] #outside the dataset display condition
# Out:
#      name  Age  Subject1_marks  Subject2_marks  Total
# b   geeta   67              78              78    156
# c  sudhir   34              90              90    180

# %%
df[df["Age"]>60] # find out age greater then 60
# Out:
#     name  Age  Subject1_marks  Subject2_marks  Total
# b  geeta   67              78              78    156

# %%
df['Age'][1]
# Out:
# 67

# %% [markdown]
# # Reading csv , xlsx from local machine .

# %%
# reading CSV file from local machine
data=pd.read_csv('Downloads/employee_data.csv')  #not working

# %%
# data=pd.read_csv('path/file name.csv') #syntax
# data=pd.read_excel('path/filename.xlsx','sheet do you want')

# %%
data_file=pd.read_excel('C:/Users/SHAILESH/Downloads/P6-SuperStoreUS-2015 (4).xlsx','Orders')

# %%
data_file
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
data_file.head() #bydefault 5 records display
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
data_file.head(10)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
# 5   24847         Medium      0.05        3.28           4.20           14
# 6   24848         Medium      0.05        3.58           1.63           14
# 7   18181       Critical      0.00        4.42           4.99           15
# 8   20925         Medium      0.01       35.94           6.66           15
# 9   26267           High      0.04        2.98           1.58           16
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# ...

# %%
data_file.tail() #by default 5 records will be visible
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
#       Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 1947    Andrea Shaw  Regular Air   Small Business  Office Supplies  ...
# 1948    Andrea Shaw  Regular Air   Small Business       Technology  ...
# 1949    Marvin Reid  Regular Air   Small Business  Office Supplies  ...
# 1950  Florence Gold  Express Air   Small Business        Furniture  ...
# 1951  Tammy Buckley  Express Air         Consumer        Furniture  ...
#
# ...

# %%
data_file.tail(20)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1932   22378       Critical      0.00       19.98           5.97         3379
# 1933   20366       Critical      0.05        3.14           1.92         3379
# 1934   23181       Critical      0.03      315.98          19.99         3380
# 1935   23182       Critical      0.09      276.20          24.49         3380
# 1936   23183       Critical      0.03       63.94          14.48         3380
# 1937   24161  Not Specified      0.05       11.97           5.81         3381
# 1938   25841         Medium      0.02       28.53           1.49         3381
# 1939   22341            Low      0.04        2.98           2.03         3385
# 1940   22342            Low      0.01      125.99           8.99         3385
# 1941   23190       Critical      0.00        2.61           0.50         3386
# 1942   23191       Critical      0.04       25.38           8.99         3386
# ...

# %%
data_file[20:51] #mid data find
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 20   23612           High      0.01       17.98           8.51           32
# 21   23278         Medium      0.09      125.99           7.69           32
# 22   19355            Low      0.06      205.99           8.99           32
# 23   23654  Not Specified      0.03        4.24           5.41           33
# 24   23655  Not Specified      0.04        2.94           0.70           33
# 25   25933           High      0.00       99.99          19.99           43
# 26   18551  Not Specified      0.00      115.99           2.50           52
# 27   22117       Critical      0.07     3502.14           8.73           53
# 28   18552  Not Specified      0.02        5.98           5.79           53
# 29   20697         Medium      0.06        3.80           1.49           56
# 30   20698         Medium      0.06        1.76           0.70           56
# ...

# %%
data_file.info()  #object=string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
data_file.shape
# Out:
# (1952, 25)

# %%
data_file.size
# Out:
# 48800

# %%
data_file.dtypes #check data type
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Country                         object
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# ...

# %%
data_file.columns #check col
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
data_file['Start Date']=pd.to_datetime(data_file['Start Data']) #emp data used

# %%
data_file.describe().T # only for numerical data  (#T=transpose)
# Out:
#                        count          mean           std        min  \
# Row ID                1952.0  19916.479508   5957.595627     64.000
# Discount              1952.0      0.048975      0.031378      0.000
# Unit Price            1952.0    109.079221    393.481301      1.140
# Shipping Cost         1952.0     12.968151     17.414631      0.490
# Customer ID           1952.0   1735.376537    991.078006      3.000
# Product Base Margin   1936.0      0.515186      0.137055      0.350
# Postal Code           1952.0  51534.769467  29362.828420   1001.000
# Profit                1952.0    114.793859   1141.112387 -16476.838
# Quantity ordered new  1952.0     12.944672     13.871565      1.000
# Sales                 1952.0    985.828832   2559.900167      2.250
# Order ID              1952.0  82365.924180  19042.295798    359.000
#
#                              25%          50%           75%         max
# Row ID                19121.0000  21164.50000  23483.250000  26389.0000
# ...

# %%
# to check null value (#sum=how many values are null)
data_file.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
data_file.dropna()
data_file.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
drop_value.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# ### que. Roll no. data frame already exist what is output.
# 1] return error
#
# 2]add new col
#
# 3]replace the already exist.
#
# 4]not

# %%
d1=pd.DataFrame({"Roll number":[6,7,8]})

# %%
d1
# Out:
#    Roll number
# 0            6
# 1            7
# 2            8

# %%
d1['Roll number']=[1,2,3]

# %%
d1
# Out:
#    Roll number
# 0            1
# 1            2
# 2            3

# %% [raw]
# correct ans. -----> 4th

# %%
df=pd.read_csv('employee_data.csv')

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
df['Start Date']=pd.to_datetime(df['Start Date'])

# %%
df.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management            object
# Team                         object
# dtype: object

# %%
df2=df.drop(['Start Date'],axis=1)   #1=column 0=row

# %%
df2.head()
# Out:
#   First Name  Gender Last Login Time  Salary  Bonus % Senior Management  \
# 0    Douglas    Male        12:42 PM   97308    6.945              True
# 1     Thomas    Male         6:53 AM   61933    4.170              True
# 2      Maria  Female        11:17 AM  130590   11.858             False
# 3      Jerry    Male         1:00 PM  138705    9.340              True
# 4      Larry    Male         4:47 PM  101004    1.389              True
#
#               Team
# 0        Marketing
# 1              NaN
# 2          Finance
# 3          Finance
# 4  Client Services

# %%
df2.drop([4],axis=0) #drop 4th row
# Out:
#     First Name  Gender Last Login Time  Salary  Bonus % Senior Management  \
# 0      Douglas    Male        12:42 PM   97308    6.945              True
# 1       Thomas    Male         6:53 AM   61933    4.170              True
# 2        Maria  Female        11:17 AM  130590   11.858             False
# 3        Jerry    Male         1:00 PM  138705    9.340              True
# 5       Dennis    Male         1:35 AM  115163   10.125             False
# ..         ...     ...             ...     ...      ...               ...
# 995      Henry     NaN         6:09 AM  132483   16.655             False
# 996    Phillip    Male         6:30 AM   42392   19.675             False
# 997    Russell    Male        12:39 PM   96914    1.421             False
# 998      Larry    Male         4:45 PM   60500   11.985             False
# 999     Albert    Male         6:24 PM  129949   10.169              True
#
#                      Team
# 0               Marketing
# ...

# %%
df2.drop([4],axis=0,inplace=True)    #drop 4th row
df2.head()
# Out:
#   First Name  Gender Last Login Time  Salary  Bonus % Senior Management  \
# 0    Douglas    Male        12:42 PM   97308    6.945              True
# 1     Thomas    Male         6:53 AM   61933    4.170              True
# 2      Maria  Female        11:17 AM  130590   11.858             False
# 3      Jerry    Male         1:00 PM  138705    9.340              True
# 5     Dennis    Male         1:35 AM  115163   10.125             False
#
#         Team
# 0  Marketing
# 1        NaN
# 2    Finance
# 3    Finance
# 5      Legal

# %%
df2.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %% [markdown]
# # dropping null values

# %%
df3=df2.dropna()

# %%
df3.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %% [markdown]
# # filling the null values

# %% [markdown]
# ### 1. filling with some values.

# %%
df2.head(20)
# Out:
#    First Name  Gender Last Login Time  Salary  Bonus % Senior Management  \
# 0     Douglas    Male        12:42 PM   97308    6.945              True
# 1      Thomas    Male         6:53 AM   61933    4.170              True
# 2       Maria  Female        11:17 AM  130590   11.858             False
# 3       Jerry    Male         1:00 PM  138705    9.340              True
# 5      Dennis    Male         1:35 AM  115163   10.125             False
# 6        Ruby  Female         4:20 PM   65476   10.012              True
# 7         NaN  Female        10:43 AM   45906   11.598               NaN
# 8      Angela  Female         6:29 AM   95570   18.523              True
# 9     Frances  Female         6:51 AM  139852    7.524              True
# 10     Louise  Female         9:01 AM   63241   15.132              True
# 11      Julie  Female         3:19 PM  102508   12.637              True
# 12    Brandon    Male         1:08 AM  112807   17.492              True
# ...

# %%
df['Senior Management']=df['Senior Management'].fillna(False,inplace=True)

# %%
df.head(20)
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1      Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2       Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3       Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4       Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 5      Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# 6        Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 7         NaN  Female 2015-07-20        10:43 AM   45906   11.598
# 8      Angela  Female 2005-11-22         6:29 AM   95570   18.523
# 9     Frances  Female 2002-08-08         6:51 AM  139852    7.524
# 10     Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 11      Julie  Female 1997-10-26         3:19 PM  102508   12.637
# 12    Brandon    Male 1980-12-01         1:08 AM  112807   17.492
# ...

# %%
df2['Senior Management']=df2['Senior Management'].fillna(False,inplace=True)

# %%
df2.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management    999
# Team                  43
# dtype: int64

# %%
df.drop(['Senior Management'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#               Team
# 0        Marketing
# 1              NaN
# 2          Finance
# 3          Finance
# 4  Client Services

# %%
df.sort_values(by='Salary',inplace=True) #bydefault ascending sorting is df

# %%
# df.sort_values(by='Bonus',inplace=True)
# df.sort_values(by='Salary',inplace=True)

# %%
df.head()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 576    Michael    Male 1993-07-30         5:35 PM   35013   14.879
# 238      Kevin    Male 1982-03-25         7:31 AM   35061    5.128
# 82      Steven    Male 1980-03-30         9:20 PM   35095    8.379
# 63     Matthew    Male 2013-01-02        10:33 PM   35203   18.040
# 650    Cynthia  Female 1986-07-05         1:24 AM   35381   11.749
#
#                 Team
# 576          Product
# 238            Legal
# 82   Client Services
# 63   Human Resources
# 650          Finance

# %%
df.sort_values(by='Salary',ascending=False,inplace=True) #descending sorting

# %%
#df.sort_values(by='salary',ascending=False,inplacr=True)

# %%
df.head()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female 1996-08-13        12:21 AM  149908   18.912
# 429       Rose  Female 2015-05-28         8:40 AM  149903    5.630
# 828    Cynthia  Female 2006-07-12         8:55 AM  149684    7.864
# 186        NaN  Female 2005-02-23         9:50 PM  149654    1.825
# 160      Kathy  Female 2000-03-18         7:26 PM  149563   16.991
#
#                 Team
# 644          Finance
# 429  Human Resources
# 828          Product
# 186            Sales
# 160          Finance

# %%
df['Gender'].value_counts() # To find out male & female ratio
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %%
df['Team'].unique()
# Out:
# array(['Finance', 'Human Resources', 'Product', 'Sales', 'Marketing',
#        'Distribution', 'Legal', nan, 'Business Development',
#        'Engineering', 'Client Services'], dtype=object)

# %%
df['Team'].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
df['Team'].value_counts(normalize=True)*100 # *100=percentage count
# Out:
# Client Services         11.076280
# Finance                 10.658307
# Business Development    10.553814
# Marketing               10.240334
# Product                  9.926855
# Sales                    9.822362
# Engineering              9.613375
# Human Resources          9.508882
# Distribution             9.404389
# Legal                    9.195402
# Name: Team, dtype: float64

# %%
# to check duplicate value present 
df.duplicated().sum()
# Out:
# 0

# %%
# to remove duplicate values.
df3=df.drop_duplicates()

# %%
# to check duplicates value
df.duplicated.sum()
# to remove duplicate values
df1=df.drop_duplicates()

# %%
df.corr() # applicable on only numerical data
# Out:
#            Salary   Bonus %
# Salary   1.000000 -0.036381
# Bonus % -0.036381  1.000000
